# %%
import matplotlib.pyplot as plt
from IPython.display import IFrame
import pandas as pd
import datetime as dt
import numpy as np
import seaborn as sns
import json


rpt_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/python-data-prep/nyczips.geojson'

temp0_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/data/temp0.geojson'
temp1_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/data/temp1.geojson'

sev1_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/data/sev1.geojson'
sev2_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/data/sev2.geojson'
sev3_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/data/sev3.geojson'
sev4_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/data/sev4.geojson'
sev5_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/data/sev5.geojson'
sev6_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/data/sev6.geojson'
sev7_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/data/sev7.geojson'

sunup_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/data/sunup.geojson'
sundown_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/data/sundown.geojson'

sunny_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/data/sunny.geojson'
rainy_file = r'/Users/e5pianos/Desktop/Academic/2019 Spring/COMP4462/nyc_ems_visualization/data/rainy.geojson'

"""rh ranking

In Brooklyn: 
Sunny
8.472591170781179
Rainy
8.519945355027327


In Bronx: 
Sunny
9.573941368036294
Rainy
10.932822086165634


In Queens: 
Sunny
7.9095294582402245
Rainy
7.615994623685484


In Manhattan: 
Sunny
9.363756272387521
Rainy
8.11150234738029


In SI and Richmond: 
Sunny
7.07329004332727
Rainy
7.561616161727272

sunupdown ranking

In Brooklyn: 
Day
8.074557032033221
Night
8.780608164953914


In Bronx: 
Day
8.77570506287972
Night
10.328687703433514


In Queens: 
Day
7.19961763378137
Night
8.367570938538817


In Manhattan: 
Day
8.020259481024949
Night
10.161274175182259


In SI and Richmond: 
Day
6.7664658633493975
Night
7.339351851992069

temperature ranking

In Brooklyn: 
<0
8.542290988052113
>0
8.456892057585552

In Bronx: 
<0
9.712477395922233
>0
9.656310403644108

In Queens: 
<0
8.807276995241782
>0
7.606900288986273

In Manhattan: 
<0
9.507024265641757
>0
9.233881748053463

In SI and Richmond: 
<0
7.095921985925529
>0
7.116460905373459

In Brooklyn: 
level: 1
5.030645161258065
level: 2
6.558263069116358
level: 3
6.571446384007483
level: 4
8.06652601973207
level: 5
9.438440860120979
level: 6
9.41976666654399
level: 7
13.661323155110688

In Bronx: 
level: 1
5.1742424242954534
level: 2
6.822932816573642
level: 3
7.436072260853149
level: 4
9.65858867231755
level: 5
10.75489089546275
level: 6
11.687638230568718
level: 7
13.708264462719002

In Queens: 
level: 1
5.322357723658535
level: 2
7.191976840359806
level: 3
7.050246913399998
level: 4
7.821506849298623
level: 5
8.26850104822956
level: 6
8.318546365853386
level: 7
10.6308390022381

In Manhattan: 
level: 1
5.943262411148935
level: 2
6.599139579412999
level: 3
7.15158959530636
level: 4
9.742169540034487
level: 5
9.4042310523841
level: 6
10.606870567311171
level: 7
15.305297157678297

In SI and Richmond: 
level: 1
5.4095238095
level: 2
6.426785714142858
level: 3
6.783974359249999
level: 4
7.993192488366198
level: 5
7.275568181931818
level: 6
6.957666666439999
level: 7
8.670967742387099"""


    
    
with open(temp0_file  , 'w') as reader:
    temp0 = json.loads(reader.read())
result_temp0 = temp0
"""
with open(temp1_file  , 'r') as reader:
    temp1 = json.load(reader)
with open(sev1_file  , 'r') as reader:
    sev1 = json.load(reader)
with open(sev2_file  , 'r') as reader:
    sev2 = json.load(reader)
"""

for i in result_temp0['features']:
    if(i['properties']['borough']=='Queens'):
        i['ranking_value'] = "8.807276995241782"
    if(i['properties']['borough']=='Manhattan'):
        i['ranking_value'] = 9.507024265641757
    if(i['properties']['borough']=='SI and Richmond'):
        i['ranking_value'] = 7.095921985925529
    if(i['properties']['borough']=='Bronx'):
        i['ranking_value'] = 9.712477395922233
    if(i['properties']['borough']=='Brooklyn'):
        i['ranking_value'] = 8.542290988052113 



"""
for i in temp1['features']:
    if(i['properties']['borough']=='Queens'):
        temp1['ranking_value'] = 7.606900288986273
    if(i['properties']['borough']=='Manhattan'):
        temp1['ranking_value'] = 9.233881748053463
    if(i['properties']['borough']=='SI and Richmond'):
        temp1['ranking_value'] = 7.116460905373459
    if(i['properties']['borough']=='Bronx'):
        temp1['ranking_value'] = 9.656310403644108
    if(i['properties']['borough']=='Brooklyn'):
        temp1['ranking_value'] = 8.456892057585552 

"""
#json.dump(temp1, data)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-15-72a75542f1ce> in <module>
#     215
#     216 with open(temp0_file  , 'w') as reader:
# --> 217     temp0 = json.loads(reader.read())
#     218 """
#     219 with open(temp1_file  , 'r') as reader:
#
# UnsupportedOperation: not readable
